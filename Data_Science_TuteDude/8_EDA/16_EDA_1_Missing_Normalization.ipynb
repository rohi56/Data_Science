# %% [markdown]
# # Exploratory Data Analysis(EDA) Using Pandas
#
# ## What is EDA?
#
# **EDA (Exploratory Data Analysis)** is the process of examining a dataset to summarize its main characteristics, often using visual methods.
#
# ## It help us:
#
# - Detect patterns and relationship
# - Identify anamolies or outliners
# - Handle missing values
# - Prepare data for modelling
#
# ## Why use Pandas for EDA?
#
# Pandas is most widely-used Python Library for data manipulation and analysis.
#
# ## With Pandas, we can:
#
# - Load dataset easily (CSV, Excel, etc.)
# - Clean and transform data
# - Analyze and summarize features
# - Integrate with visualization tools like Matplotlib & Seaborn

# %% [markdown]
# ## Dataset Overview and Initial Inspection
#
# ### Load Dataset

# %%
import pandas as pd
data = pd.read_csv("data_clean.csv") #reading csv file
data.head()
# Out:
#    Unnamed: 0  Ozone  Solar.R  Wind Temp C Month  Day  Year  Temp Weather
# 0           1   41.0    190.0   7.4     67     5    1  2010    67       S
# 1           2   36.0    118.0   8.0     72     5    2  2010    72       C
# 2           3   12.0    149.0  12.6     74     5    3  2010    74      PS
# 3           4   18.0    313.0  11.5     62     5    4  2010    62       S
# 4           5    NaN      NaN  14.3     56     5    5  2010    56       S

# %%
databackup = data # Taking backup before Any changes, so we can restore any point of time.

# %%
data.tail()
# Out:
#      Unnamed: 0  Ozone  Solar.R  Wind Temp C Month  Day  Year  Temp Weather
# 153         154   41.0    190.0   7.4     67     5    1  2010    67       C
# 154         155   30.0    193.0   6.9     70     9   26  2010    70      PS
# 155         156    NaN    145.0  13.2     77     9   27  2010    77       S
# 156         157   14.0    191.0  14.3     75     9   28  2010    75       S
# 157         158   18.0    131.0   8.0     76     9   29  2010    76       C

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  158 non-null    int64
#  1   Ozone       120 non-null    float64
#  2   Solar.R     151 non-null    float64
#  3   Wind        158 non-null    float64
#  4   Temp C      158 non-null    object
#  5   Month       158 non-null    object
#  6   Day         158 non-null    int64
#  7   Year        158 non-null    int64
#  8   Temp        158 non-null    int64
#  9   Weather     155 non-null    object
# dtypes: float64(3), int64(4), object(3)
# memory usage: 12.5+ KB

# %%
data.shape
# Out:
# (158, 10)

# %%
data.dtypes
# Out:
# Unnamed: 0      int64
# Ozone         float64
# Solar.R       float64
# Wind          float64
# Temp C         object
# Month          object
# Day             int64
# Year            int64
# Temp            int64
# Weather        object
# dtype: object

# %%
data.describe() # basic statstics
# Out:
#        Unnamed: 0       Ozone     Solar.R        Wind         Day    Year  \
# count  158.000000  120.000000  151.000000  158.000000  158.000000   158.0
# mean    79.500000   41.583333  185.403974    9.957595   16.006329  2010.0
# std     45.754781   32.620709   88.723103    3.511261    8.997166     0.0
# min      1.000000    1.000000    7.000000    1.700000    1.000000  2010.0
# 25%     40.250000   18.000000  119.000000    7.400000    8.000000  2010.0
# 50%     79.500000   30.500000  197.000000    9.700000   16.000000  2010.0
# 75%    118.750000   61.500000  257.000000   11.875000   24.000000  2010.0
# max    158.000000  168.000000  334.000000   20.700000   31.000000  2010.0
#
#              Temp
# count  158.000000
# mean    77.727848
# std      9.377877
# min     56.000000
# 25%     72.000000
# 50%     78.500000
# 75%     84.000000
# max     97.000000

# %% [markdown]
# **Note**: Sometimes few of data point have wrong value and we didn't find during EDA.
# During Machine Learning model, it through error, as it is string and expected as numeric,
# Like here month is numeric value so we convert object to nunmeric.

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  158 non-null    int64
#  1   Ozone       120 non-null    float64
#  2   Solar.R     151 non-null    float64
#  3   Wind        158 non-null    float64
#  4   Temp C      158 non-null    object
#  5   Month       158 non-null    object
#  6   Day         158 non-null    int64
#  7   Year        158 non-null    int64
#  8   Temp        158 non-null    int64
#  9   Weather     155 non-null    object
# dtypes: float64(3), int64(4), object(3)
# memory usage: 12.5+ KB

# %%
#data['Month']= pd.to_numeric(data['Month'])
#the above line will show error

# %%
data['Month'].head(25)
# Out:
# 0       5
# 1       5
# 2       5
# 3       5
# 4       5
# 5       5
# 6       5
# 7       5
# 8       5
# 9       5
# 10      5
# 11      5
# 12      5
# 13      5
# 14      5
# 15      5
# 16      5
# 17      5
# 18      5
# 19      5
# 20      5
# 21      5
# 22      5
# 23    May
# 24      5
# Name: Month, dtype: object

# %%
# Since May is invalid Let us replace with 5.
data['Month'] =data['Month'].replace('May',5)

# %%
data['Month'].head(25)
# Out:
# 0     5
# 1     5
# 2     5
# 3     5
# 4     5
# 5     5
# 6     5
# 7     5
# 8     5
# 9     5
# 10    5
# 11    5
# 12    5
# 13    5
# 14    5
# 15    5
# 16    5
# 17    5
# 18    5
# 19    5
# 20    5
# 21    5
# 22    5
# 23    5
# 24    5
# Name: Month, dtype: object

# %%
data['Month'] = pd.to_numeric(data['Month'], errors = 'coerce') # error = 'coerce' for ce to convert any other value like May to NA.
data['Temp C'] = pd.to_numeric(data['Temp C'], errors = 'coerce')
data['Weather'] = data['Weather'].astype('category')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  158 non-null    int64
#  1   Ozone       120 non-null    float64
#  2   Solar.R     151 non-null    float64
#  3   Wind        158 non-null    float64
#  4   Temp C      157 non-null    float64
#  5   Month       158 non-null    int64
#  6   Day         158 non-null    int64
#  7   Year        158 non-null    int64
#  8   Temp        158 non-null    int64
#  9   Weather     155 non-null    category
# dtypes: category(1), float64(4), int64(5)
# memory usage: 11.5 KB

# %% [markdown]
# ## Duplicates

# %%
data.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 153    False
# 154    False
# 155    False
# 156    False
# 157    False
# Length: 158, dtype: bool

# %%
data.duplicated().sum()
# Out:
# np.int64(0)

# %%
data[data.duplicated()].shape
#This indicates there are no duplicate records
# Out:
# (0, 10)

# %%
#Print the duplicate rows
data[data.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, Ozone, Solar.R, Wind, Temp C, Month, Day, Year, Temp, Weather]
# Index: []

# %%
# In case duplicate record found, it need to drop as follows.
data = data.drop_duplicates()

# %%
data.shape
# Out:
# (158, 10)

# %% [markdown]
# ## Drop column which are unnecessary

# %%
# Droping 'Unname: 0' column as it is found unnecessary
data.head()
# Out:
#    Unnamed: 0  Ozone  Solar.R  Wind  Temp C  Month  Day  Year  Temp Weather
# 0           1   41.0    190.0   7.4    67.0      5    1  2010    67       S
# 1           2   36.0    118.0   8.0    72.0      5    2  2010    72       C
# 2           3   12.0    149.0  12.6    74.0      5    3  2010    74      PS
# 3           4   18.0    313.0  11.5    62.0      5    4  2010    62       S
# 4           5    NaN      NaN  14.3    56.0      5    5  2010    56       S

# %%
databackup1 = data # Taking backup one more time before removing anything

# %%
data = data.drop('Unnamed: 0', axis=1)

# %%
data.head()
# Out:
#    Ozone  Solar.R  Wind  Temp C  Month  Day  Year  Temp Weather
# 0   41.0    190.0   7.4    67.0      5    1  2010    67       S
# 1   36.0    118.0   8.0    72.0      5    2  2010    72       C
# 2   12.0    149.0  12.6    74.0      5    3  2010    74      PS
# 3   18.0    313.0  11.5    62.0      5    4  2010    62       S
# 4    NaN      NaN  14.3    56.0      5    5  2010    56       S

# %%
# Droping 'Temp C' column as 'Temp C' and 'Temp' having same data
data = data.drop('Temp C', axis=1)

# %%
data.head()
# Out:
#    Ozone  Solar.R  Wind  Month  Day  Year  Temp Weather
# 0   41.0    190.0   7.4      5    1  2010    67       S
# 1   36.0    118.0   8.0      5    2  2010    72       C
# 2   12.0    149.0  12.6      5    3  2010    74      PS
# 3   18.0    313.0  11.5      5    4  2010    62       S
# 4    NaN      NaN  14.3      5    5  2010    56       S

# %% [markdown]
# ## Rename the column

# %%
# rename the 'Solar.R' column
data = data.rename({'Solar.R': 'Solar'}, axis =1)

# %%
data.head()
# Out:
#    Ozone  Solar  Wind  Month  Day  Year  Temp Weather
# 0   41.0  190.0   7.4      5    1  2010    67       S
# 1   36.0  118.0   8.0      5    2  2010    72       C
# 2   12.0  149.0  12.6      5    3  2010    74      PS
# 3   18.0  313.0  11.5      5    4  2010    62       S
# 4    NaN    NaN  14.3      5    5  2010    56       S

# %% [markdown]
# ## Why Handle Missing Values?
#
# - Algorithms cannot handle null/NaN values.
# - Imputing them reduces bias and maintains dataset usability.
#
# ## How to Find Missing Values

# %%
cols = data.columns
cols
# Out:
# Index(['Ozone', 'Solar', 'Wind', 'Month', 'Day', 'Year', 'Temp', 'Weather'], dtype='object')

# %%
import seaborn as sns
cols = data.columns
colours = ['#000099', '#ffff00'] #Specify the color yellow: missing and Blue: Not missing
sns.heatmap(data[cols].isnull(),
            cmap=sns.color_palette(colours))
# Out:
# <Axes: >

# %%
# Observation
# Yellow color band shows missing values in each column like Ozone, Solar, Weather ect.
# as it show highest missing values are Ozone columns.

# %%
data.isnull().sum()
# Out:
# Ozone      38
# Solar       7
# Wind        0
# Month       0
# Day         0
# Year        0
# Temp        0
# Weather     3
# dtype: int64

# %% [markdown]
# # Handling Missing (NaN) Values
#
# ## Overview
# Missing values (NaN) are common in datasets and need to be handled before analysis or modeling.
#
# ## Common Techniques
#
# | Method                | Description                                      | When to Use                          | Example |
# |----------------------|--------------------------------------------------|--------------------------------------|---------|
# | Drop Rows            | Remove rows with missing values                  | When few rows are missing            | `df.dropna()` |
# | Drop Columns         | Remove columns with many missing values          | When column is not important         | `df.drop(columns=['col'])` |
# | Mean Imputation      | Replace with column mean                         | Numerical data, no outliers          | `df['col'].fillna(df['col'].mean())` |
# | Median Imputation    | Replace with median                              | Numerical data with outliers         | `df['col'].fillna(df['col'].median())` |
# | Mode Imputation      | Replace with most frequent value                 | Categorical data                     | `df['col'].fillna(df['col'].mode()[0])` |
# | Forward Fill         | Fill with previous value                         | Time series data                     | `df.fillna(method='ffill')` |
# | Backward Fill        | Fill with next value                             | Time series data                     | `df.fillna(method='bfill')` |
# | Interpolation        | Estimate values based on trend                   | Continuous data                      | `df.interpolate()` |
# | Model-based Impute   | Predict missing values using ML models           | Advanced use cases                   | `KNNImputer`, `IterativeImputer` |
#
# ## Notes
# - Always analyze missing data before choosing a method.
# - Avoid blindly filling values—it may introduce bias.
# - Consider domain knowledge when imputing data.

# %%
#Checking missing in Ozone

# %%
print("Missing in Ozone:", data['Ozone'].isnull().sum())
# Out:
# Missing in Ozone: 38

# %%
import seaborn as sns
import matplotlib.pyplot as plt

#Boxplot to check outliners
plt.figure(figsize =(8,4))
sns.boxplot(y=data['Ozone'])
plt.title('Boxplot of Ozone - Before Imputation')
plt.show()

# %%
# There are outliners, still we confirm with one statistical method

# %%
# IQR(Inter Quartile Range ) = Q3-Q1

# %%
# Calculate Q1 and Q3
Q1 = data['Ozone'].quantile(0.25)
Q3 = data['Ozone'].quantile(0.75)
IQR = Q3-Q1

# Define outliner bounds
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Find Outliners
outliners = data[(data['Ozone']< lower_bound)| (data['Ozone']> upper_bound)]
print("Number of outliners in Ozone Column:", outliners.shape[0])
# Out:
# Number of outliners in Ozone Column: 2

# %%
# Hence as per strategy we will replace Ozone column with median

# %%
# Fill with median
ozone_median = data['Ozone'].median()
data['Ozone'].fillna(ozone_median, inplace = True)
print("Filled with median:", ozone_median)
# Out:
# Filled with median: 30.5
# C:\Users\C5144878\AppData\Local\Temp\ipykernel_26052\142002930.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['Ozone'].fillna(ozone_median, inplace = True)

# %%
# Check missing in Ozone
data['Ozone'].isnull().sum()
# Out:
# np.int64(0)

# %%
#Now we will check for Solar Column
#Print NA value in Solar
data['Solar'].isnull().sum()
# Out:
# np.int64(7)

# %%
# Now Boxplot to check outliners in Solar Features(column)
plt.figure(figsize = (8,4))
sns.boxplot(y = data['Solar'])
plt.title("Boxplot of Solar - Before Imputation")
plt.show()

# %%
# Also check using IQR
Q1 = data['Solar'].quantile(0.25)
Q3 = data['Solar'].quantile(0.75)
IQR = Q3-Q1

# Define Outliner Bound
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Find Outliners
outliners = data[(data['Solar']< lower_bound) | (data['Solar']> upper_bound)]
print("Number of outliners in Solar Column:", outliners.shape[0])
# Out:
# Number of outliners in Solar Column: 0

# %%
# As there is no outliners in 'Solar' feature(column) we will replace the NA with mean
solar_mean = data['Solar'].mean()
solar_mean
# Out:
# np.float64(185.40397350993376)

# %%
# Replace the NA with mean in Solar feature
data['Solar'].fillna(solar_mean, inplace = True)
# Out:
# C:\Users\C5144878\AppData\Local\Temp\ipykernel_26052\1079289103.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['Solar'].fillna(solar_mean, inplace = True)

# %%
# Check the NA count in Solar to verify
data['Solar'].isnull().sum()
# Out:
# np.int64(0)

# %%
# Missing value imputation for Categorical Value
#print Missing value in Weather Feature
print("Number of missing Value in 'Weather':", data['Weather'].isnull().sum())
# Out:
# Number of missing Value in 'Weather': 3

# %%
# So we will replace it with mode
weather_mode = data['Weather'].mode()[0]
weather_mode
# Out:
# 'S'

# %%
# Fill the null value with weather_mode
data.fillna({'Weather': weather_mode}, inplace=True)

# %%
# Verify an NA value is there

print("Number of missing Value in 'Weather':", data['Weather'].isnull().sum())
# Out:
# Number of missing Value in 'Weather': 0

# %%
# Verify again do we have any null vale
data.isnull().sum()
# Out:
# Ozone      0
# Solar      0
# Wind       0
# Month      0
# Day        0
# Year       0
# Temp       0
# Weather    0
# dtype: int64

# %% [markdown]
# ## How to detect Outlier

# %%
data.boxplot()
# Out:
# <Axes: >

# %%
# Observation/Inference
#IN wind and Ozone, outliners are present and observed.

# %% [markdown]
# ## Detect Outliners Using IQR(Alternate Method)

# %%
# Calculate Q1 and Q3
Q1 = data['Wind'].quantile(0.25)
Q3 = data['Wind'].quantile(0.75)
IQR = Q3 - Q1

# Define outliner bound
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Find Outliers
outliners = data[(data['Wind']< lower_bound) | (data['Wind']> upper_bound)]
print("Number of outliers in Wind feature:",outliners.shape[0])
# Out:
# Number of outliers in Wind feature: 2

# %%
median_value = data['Wind'].median()
median_value
# Out:
# 9.7

# %%
# Replace the outlier with the median value
data.loc[data['Wind']< lower_bound, 'Wind'] = median_value
data.loc[data['Wind']> upper_bound, 'Wind'] = median_value

# %%
# To confirm outliner imputed
plt.figure(figsize = (8,4))
sns.boxplot(y = data['Wind'])
plt.title("Boxplot of Wind - After Imputation")
plt.show()

# %% [markdown]
# **Note** :  After imputation, sometime boxplt may still show some point due to recalculated IQR based on new data. These are not necessarily bad data, just statistical boundaries shifting.

# %%
outliners = data[(data['Wind']< lower_bound) | (data['Wind']> upper_bound)]
print("Number of outliers in Wind feature:",outliners.shape[0])
# Out:
# Number of outliers in Wind feature: 0

# %%
## Similarly for Ozone feature
# Calculate Q1 and Q3
Q1 = data['Ozone'].quantile(0.25)
Q3 = data['Ozone'].quantile(0.75)
IQR = Q3-Q1

# Define outliner bounds
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Find Outliners
outliners = data[(data['Ozone']< lower_bound)| (data['Ozone']> upper_bound)]
print("Number of outliners in Ozone Column:", outliners.shape[0])
# Out:
# Number of outliners in Ozone Column: 16

# %%
# Fill with median
ozone_median = data['Ozone'].median()
ozone_median
# Out:
# 30.5

# %%
data.loc[data['Ozone']< lower_bound, 'Ozone'] = ozone_median
data.loc[data['Ozone']> upper_bound, 'Ozone'] = ozone_median

# %%
# Find Outliners
outliners = data[(data['Ozone']< lower_bound)| (data['Ozone']> upper_bound)]
print("Number of outliners in Ozone Column:", outliners.shape[0])
# Out:
# Number of outliners in Ozone Column: 0

# %%
plt.figure(figsize = (8,4))
sns.boxplot(y = data['Ozone'])
plt.title("Outliner for Ozone Data")
plt.show()

# %% [markdown]
# ## Scatter plot and Correlation Analysis

# %%
sns.pairplot(data)

# %%
## Here one can see relation between two different variables like Ozone with Temp, Solar with Temp etc.
## One canc heck with positive or negative co relation or neutral, also linear or non linear.

# %%
# Correlation
#data.corr()
data.select_dtypes(include = 'number').corr()
# Out:
#           Ozone     Solar      Wind     Month       Day  Year      Temp
# Ozone  1.000000  0.288578 -0.354190  0.120973 -0.066719   NaN  0.511967
# Solar  0.288578  1.000000 -0.044178 -0.079196 -0.149606   NaN  0.260473
# Wind  -0.354190 -0.044178  1.000000 -0.123958  0.055928   NaN -0.420121
# Month  0.120973 -0.079196 -0.123958  1.000000  0.052646   NaN  0.402942
# Day   -0.066719 -0.149606  0.055928  0.052646  1.000000   NaN -0.124538
# Year        NaN       NaN       NaN       NaN       NaN   NaN       NaN
# Temp   0.511967  0.260473 -0.420121  0.402942 -0.124538   NaN  1.000000

# %%
# Here co relation value like Temp with Ozone is 0.51, which is shows it is positive correlation
# Similarly there is negative corellation between win with Ozone, -0.35 which is more.

# %% [markdown]
# ## Dummy Variable
#
# ### What is Dummy Variable?
#
# A **Dummy Variable** is a numeric(0/1) representation of **categorical data** in machine learning and statistical models.
#
# ### Why is it required?
#
# - Most algiorithms **cannot understand text** - they need numbers.
# - Dummy Variable **converts categories into binary format,** allowing models to process them effectively.
# - For example a column `Gender` with values `Male` and `Female` becomes:
#
#   |Gender_Male|Gender_Female|
#   |-------------|------------|
#   |1           |0           |
#   |0           |1           |

# %%
data.head()
# Out:
#    Ozone       Solar  Wind  Month  Day  Year  Temp Weather
# 0   41.0  190.000000   7.4      5    1  2010    67       S
# 1   36.0  118.000000   8.0      5    2  2010    72       C
# 2   12.0  149.000000  12.6      5    3  2010    74      PS
# 3   18.0  313.000000  11.5      5    4  2010    62       S
# 4   30.5  185.403974  14.3      5    5  2010    56       S

# %%
# Creating dummy variables for weather column
#data = pd.get_dummies(data,columns= ['Weather'])

# %%
data.head()
# Out:
#    Ozone       Solar  Wind  Month  Day  Year  Temp Weather
# 0   41.0  190.000000   7.4      5    1  2010    67       S
# 1   36.0  118.000000   8.0      5    2  2010    72       C
# 2   12.0  149.000000  12.6      5    3  2010    74      PS
# 3   18.0  313.000000  11.5      5    4  2010    62       S
# 4   30.5  185.403974  14.3      5    5  2010    56       S

# %%
# Weather column is converted into Weather_C, Weather_PS, Weather_S are created with one column
# Value as `, rest are 0

# %%
data['Weather'].value_counts()
# Out:
# Weather
# S     62
# C     49
# PS    47
# Name: count, dtype: int64

# %%
#Note: if Weather_C, Weather_PS, Weather_S columns shows like true or false instead of 0 and 1
#Use following code.
data = pd.get_dummies(data, columns = ['Weather']).astype(int) #Convert into int will resolve an issue.

# %%
data.head()
# Out:
#    Ozone  Solar  Wind  Month  Day  Year  Temp  Weather_C  Weather_PS  \
# 0     41    190     7      5    1  2010    67          0           0
# 1     36    118     8      5    2  2010    72          1           0
# 2     12    149    12      5    3  2010    74          0           1
# 3     18    313    11      5    4  2010    62          0           0
# 4     30    185    14      5    5  2010    56          0           0
#
#    Weather_S
# 0          1
# 1          0
# 2          0
# 3          1
# 4          1

# %% [markdown]
# ## Normalization of the data
#
# ### Normalization: The Basics
#
# Normalization is a technique used in data preprocessing to scale  the value of numerical features to a specific range.
#
# This ensure that no feature dominates other purely due to its scale, Whic is especially important for machine learning algorithms
#
# sensitive to feature magnitudes(e.g., gradient descent, K-NN).
#
#
# *Two Common normalization techniques are **`StandardScaler`** and **`MinMaxScaler`***

# %%
# Normalization of the data
from numpy import set_printoptions
from sklearn.preprocessing import MinMaxScaler

# %%
data.values
# Out:
# array([[ 41, 190,   7, ...,   0,   0,   1],
#        [ 36, 118,   8, ...,   1,   0,   0],
#        [ 12, 149,  12, ...,   0,   1,   0],
#        ...,
#        [ 30, 145,  13, ...,   0,   0,   1],
#        [ 14, 191,  14, ...,   0,   0,   1],
#        [ 18, 131,   8, ...,   1,   0,   0]], shape=(158, 10))

# %%
array = data.values
array
# Out:
# array([[ 41, 190,   7, ...,   0,   0,   1],
#        [ 36, 118,   8, ...,   1,   0,   0],
#        [ 12, 149,  12, ...,   0,   1,   0],
#        ...,
#        [ 30, 145,  13, ...,   0,   0,   1],
#        [ 14, 191,  14, ...,   0,   0,   1],
#        [ 18, 131,   8, ...,   1,   0,   0]], shape=(158, 10))

# %%
scaler = MinMaxScaler(feature_range=(0,1))
rescaledX = scaler.fit_transform(array)

# %%
# Transformed data
set_printoptions(precision =2)
print(rescaledX[0:5,:])
# Out:
# [[0.51 0.56 0.35 0.   0.   0.   0.27 0.   0.   1.  ]
#  [0.44 0.34 0.41 0.   0.03 0.   0.39 1.   0.   0.  ]
#  [0.14 0.43 0.65 0.   0.07 0.   0.44 0.   1.   0.  ]
#  [0.22 0.94 0.59 0.   0.1  0.   0.15 0.   0.   1.  ]
#  [0.37 0.54 0.76 0.   0.13 0.   0.   0.   0.   1.  ]]

# %% [markdown]
# # Key Differences Between StandardScaler and MinMaxScaler
#
# | Feature        | StandardScaler                                      | MinMaxScaler                                      |
# |---------------|-----------------------------------------------------|--------------------------------------------------|
# | Purpose       | Centers and scales data (mean = 0, std = 1)         | Scales data to a fixed range (e.g., [0, 1])      |
# | Effect        | Removes mean and variance differences               | Compresses data into the specified range         |
# | Output Range  | Not fixed; depends on data distribution             | Fixed, typically [0, 1] or custom range          |
# | Sensitivity   | Affected by outliers but less than MinMaxScaler     | Highly sensitive to outliers                     |
# | Use Case      | For algorithms sensitive to variance or normality   | For algorithms needing uniform range of values   |

# %%
# StandardScaler() mean, 1 stdev
from sklearn.preprocessing import StandardScaler

# %%
array = data.values
scaler = StandardScaler()
scaler.fit(array)
rescaledX = scaler.transform(array)

# Summarize transformed data
set_printoptions(precision=2)
print(rescaledX[0:5,:])
# Out:
# [[ 0.59  0.05 -0.72 -1.42 -1.67  0.   -1.15 -0.67 -0.65  1.24]
#  [ 0.29 -0.78 -0.41 -1.42 -1.56  0.   -0.61  1.49 -0.65 -0.8 ]
#  [-1.15 -0.42  0.81 -1.42 -1.45  0.   -0.4  -0.67  1.54 -0.8 ]
#  [-0.79  1.48  0.51 -1.42 -1.34  0.   -1.68 -0.67 -0.65  1.24]
#  [-0.07 -0.    1.43 -1.42 -1.23  0.   -2.32 -0.67 -0.65  1.24]]

# %%
# Here data has been normalized thhis data is grneralized
# Hence it can be used for further modeling where, model will not be biased on any features.

# %% [markdown]
# ## Summary
#
# - Missing Values and Impuation
# - Outliners detection and Imputation
# - Feature correlation
# - Feature scaling
