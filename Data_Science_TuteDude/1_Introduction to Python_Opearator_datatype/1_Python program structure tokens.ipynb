# %% [markdown]
# ##  Structure of a Python Program

# %%
# This is comment

# %%
# 1. Import Statements
# --------------------
# Used to import built-in or external libraries
import math  # Importing built-in math module

# %%
# this is comment
math.sqrt(9)
# Out:
# 3.0

# %%
# 2. Comments
# -----------
# Single-line comment starts with '#'
# Comments are ignored by the Python interpreter and used for documentation

# %%
'''
hello every one
this is multiline comment
'''
print('this is multiline comment')
# Out:
# this is multiline comment

# %%
# hello every one
# this is multiline comment
# press ctrl + /(forward slash) together
print('this is multiline comment')
# Out:
# this is multiline comment

# %%
# 3. Variable Declarations
# ------------------------
# Variables are containers for storing data values
number1 = 25          # Example integer value
number2 = 9.5         # Example float value
message = "Welcome!"  # Example string value

# %%
print(number2)
# Out:
# 9.5

# %%
print(message)
# Out:
# Welcome!

# %%
# 4. Using Imported Modules
# -------------------------
# Using a function from the 'math' module to find square root
sqrt_value = math.sqrt(number1)

# %%
# 5. Output Statement
# -------------------
# Used to display output on the screen
print("The square root of", number1, "is:", sqrt_value)

# End of Program
# Out:
# The square root of 25 is: 5.0

# %% [markdown]
# ## Quiz time

# %% [markdown]
# consider there is a function name randint(n1,n2) to generate any one random number between n1 and n2 range and
# for that one has to use library name  random, Task is to write two line of code how to use it as we did in math.sqrt()

# %%
# Try your code here

# %%
import random

# %%
random.randint(1,11)
# Out:
# 6

# %% [markdown]
# ## Understanding the print() Command, various styles of print()

# %%
number1=90
number2=78

# %%
sum_result=number1+number2

# %%
print('sum of',number1,'and ',number2,'are',sum_result)
# Out:
# sum of 90 and  78 are 168

# %%
print("the sum of ",number1, "and" ,number2,"is",sum_result)
# Out:
# the sum of  90 and 78 is 168

# %%
# Displaying Output

print("The sum of", number1, "and", number2, "is:", sum_result)
# Out:
# The sum of 90 and 78 is: 168

# %%
print("sum is ",sum_result)
# Out:
# sum is  168

# %% [markdown]
# ##  Tokens, Keywords, and Identifiers

# %%
#Tokens are smalles units in python  like constant, variable, operator etc.

# %%
import keyword
print("Python Keywords:", keyword.kwlist)  # Display all Python keywords
# Out:
# Python Keywords: ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %%
# variables and identifiers are same.

# %% [markdown]
# ## Valid and Invalid Identifiers

# %%
valid_identifier1 = "EmployeeName"
valid_identifier2 = "_salary"
valid_identifier3 = "totalRevenue2023"

# %%
invalid_identifier1 = "2name"  # Invalid: Cannot start with a number
invalid_identifier2 = "class"  # Invalid: Cannot use keywords as identifiers

# %% [markdown]
# ![Screenshot%202025-05-25%20162300.png](attachment:Screenshot%202025-05-25%20162300.png)

# %%
class1=10
print(class1)
# Out:
# 10

# %%
print("Valid Identifiers:", valid_identifier1, valid_identifier2, valid_identifier3)
print("Invalid Identifiers (Will cause errors if used):", "2name", "class")
# Out:
# Valid Identifiers: EmployeeName _salary totalRevenue2023
# Invalid Identifiers (Will cause errors if used): 2name class

# %% [markdown]
# ### Quiz Time
# ### mention reason for invalid identifier in following list
# 2var
#
# my-name
#
# class
#
# first name
#
# price$

# %% [markdown]
# 2var: *Starting with Number*
#
# my-name: *Contain Special character*
#
# class: *Class is the keyword*
#
# first name: *Contain space*
#
# price$ : *Contain Special character*

# %% [markdown]
# ## Variables and Data Types

# %%
sales_count = 500       # Integer
discount = 200.50       # Float
product_name = "Laptop" # String
is_available = True     # Boolean

# %%
type(sales_count)
# Out:
# int

# %%
type(is_available)
# Out:
# bool

# %%
print(type(sales_count), type(discount), type(product_name), type(is_available))
# Out:
# <class 'int'> <class 'float'> <class 'str'> <class 'bool'>

# %% [markdown]
# ## Thank you

# %% [markdown]
# ## Operators in Python

# %%
## Arithmetic Operators
num1 = 10
num2 = 5
addition = num1 + num2  # Addition
multiplication = num1 * num2  # Multiplication

# %%
print("Addition:", addition)
print("Multiplication:", multiplication)
# Out:
# Addition: 15
# Multiplication: 50

# %% [markdown]
# ## Relational Operators

# %%
num1
# Out:
# 10

# %%
num2
# Out:
# 5

# %%
num1=10
num2=10

is_greater = num1 > num2  # Greater than

is_equal = num1 == num2  # Equal to

print("Is Greater:", is_greater)
print("Is Equal:", is_equal)
# Out:
# Is Greater: False
# Is Equal: True

# %% [markdown]
# ##  Hands-on Problem solving: Retail Sales Calculation
#
# ### calculate total price of tshirt after discount

# %%
# tshirt_discount = 10 % 
tshirt_price = 1500
tshirt_discount = 10 
final_price = tshirt_price - (tshirt_discount/100)*tshirt_price

print("T shirt Price:", tshirt_price)
print("Discount Applied:", tshirt_discount)
print("Final Price after Discount:", final_price)
# Out:
# T shirt Price: 1500
# Discount Applied: 10
# Final Price after Discount: 1350.0
